# %% [markdown]
# <a href="https://colab.research.google.com/github/Danieloku/algoalgo/blob/main/mapa_de_calor_y_boxplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

#Daniel Sánchez Cataño A01663268
#Daniel Avendaño Llanos A01658305
#Alejandra Trejo Reveles A01653181
# Out:
#      <input type="file" id="files-3b4bd329-31e4-4625-ac5c-e5ca97c2ce93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b4bd329-31e4-4625-ac5c-e5ca97c2ce93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# Carga el archivo CSV
df = pd.read_csv('covid19_tweets.csv')

# Muestra las primeras filas del DataFrame
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
#Mapa de calor
df.corr()
# Out:
# <ipython-input-20-fe91f8e76a8d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              NaN

# %%
sns.heatmap(df.corr());
# Out:
# <ipython-input-19-f044f2f5ad42>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %%
#Cajas y bigotes
import seaborn as sns
sns.boxplot(data=df["user_followers"], showfliers=False)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df["user_friends"], showfliers=False)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df["user_favourites"], showfliers=False)
# Out:
# <Axes: >

# %%
#histogramas
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(df["user_friends"])
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(df["user_followers"])
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(df["user_favourites"])
plt.show()

# %%
4
# Out:
# 4

# %% [markdown]
# **¿Hay alguna variable que no aporta información?**
# todas las que tengan una correlacion baja no nos son de tanta importancia para este ejercicio, ya que son factores muy independientes y a veces son texto, no quiere decir que sean inutiles pero no nos sirven ahora
#
# **Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?**
# me quedaría unicamente con friends followers y favourites, los verificado siento que no llegan a tener una suficiente relevancia para el estudio y los demás son de meramente texto por lo que no podemos analizarlo
#
# **¿Existen variables que tengan datos extraños?**
# pues esta raro como los usuarios llegan a tener un maximo de amigos tan alto sobre todo,  cuando la media se encuentra en los 500 amigos por usuario.
#
# **Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte?**
# Si, todas las variables que nos aportan información útil se encuentran en rangos similares, lo cuál si repercute de forma directa el estudio, debido a que a partir de dicha similitud se pueden obtener patrones de comportamiento para algún caso específico a estudiar.
#
# **¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos? **
# el de sgeguidores y favoritos se parecen
